# %%
import pandas as pd

# %%
input_mv = pd.read_parquet('/n/netscratch/mzitnik_lab/Lab/rconci/BIOMM/numerics/mv_filtered.bin')

# %%
input_mv.columns
# Out:
# Index(['subject_id', 'hadm_id', 'item_id', 'input_name', 'input_class',
#        'start_time', 'end_time', 'rate', 'rate_uom', 'rate/weight',
#        'item_label', 'rate_weight_norm', 'rate_norm', 'prev_rate', 'trigger',
#        'trigger_reason', 'action_cluster_id', 'action_cluster_size',
#        'action_cluster_rank', 'first', 'last', 'absolute_timestamp',
#        'wf_time_delta_s'],
#       dtype='object')

# %%
input_mv[input_mv['rate_weight_norm']>100][['hadm_id', 'item_id', 'item_label', 'rate', 'rate/weight','rate_weight_norm']]
# Out:
#        hadm_id  item_id     item_label        rate  rate/weight  \
# 4021    154972   221749  Phenylephrine  143.846568   143.846568
# 12497   119210   221429        Esmolol  101.547382   101.547382
# 12498   119210   221429        Esmolol  101.547391   101.547391
# 12499   119210   221429        Esmolol  106.171345   106.171345
# 12500   119210   221429        Esmolol  104.733982   104.733982
# ...        ...      ...            ...         ...          ...
# 20959   169761   221429        Esmolol  149.803916   149.803916
# 20960   169761   221429        Esmolol  149.825520   149.825520
# 20965   169761   221429        Esmolol  149.803916   149.803916
# 20966   169761   221429        Esmolol  101.493226   101.493226
# 31937   111707   221429        Esmolol  100.074248   100.074248
#
#        rate_weight_norm
# 4021         143.846568
# 12497        101.547382
# 12498        101.547391
# 12499        106.171345
# 12500        104.733982
# ...                 ...
# ...

# %%
waveform_df = pd.read_parquet('/n/netscratch/mzitnik_lab/Lab/rconci/BIOMM/numerics/smoothed_numerics.bin')

# %%
waveform_df.columns
# Out:
# Index(['hadm_id', 'record_name', 'absolute_timestamp', 'ABP MEAN', 'NBP MEAN',
#        'CVP', 'HR', 'RESP', 'record_start_time', 'record_end_time',
#        'icu_admission_time', 'time_seconds', 'ABP MEAN_z', 'CVP_z', 'HR_z',
#        'RESP_z'],
#       dtype='object')

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA available: False
# CUDA device count: 0

# %%
import os, sys, torch, subprocess, textwrap

print("python:", sys.executable)
print("torch:", torch.__version__, "| torch.version.cuda:", torch.version.cuda)
print("CUDA_VISIBLE_DEVICES:", os.environ.get("CUDA_VISIBLE_DEVICES"))
print("torch.cuda.is_available():", torch.cuda.is_available())
print("torch.cuda.device_count():", torch.cuda.device_count())

# shell-side facts from the *same process*
print("\nhostname / nvidia-smi:")
print(subprocess.run(["hostname"], capture_output=True, text=True).stdout.strip())
print(textwrap.shorten(subprocess.run(["bash","-lc","nvidia-smi || echo NO_NVIDIA"], capture_output=True, text=True).stdout, width=3000))
# Out:
# python: /n/home00/rconci/micromamba/envs/trident/bin/python
# torch: 2.6.0+cu124 | torch.version.cuda: 12.4
# CUDA_VISIBLE_DEVICES: None
# torch.cuda.is_available(): True
# torch.cuda.device_count(): 1
#
# hostname / nvidia-smi:
# holygpu8a19303.rc.fas.harvard.edu
# ...
