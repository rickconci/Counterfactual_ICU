# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import pickle

# %%
context_tensors_meta = '/Users/riccardoconci/Local_documents/Counterfactual_ICU/data/mimic_3_data/processed_data/context_tensors_output/context_tensors_metadata.pkl'

with open(context_tensors_meta, 'rb') as f:
    context_tensors_meta = pickle.load(f)

# %%
context_tensors_meta
# Out:
# {'physio_context': {'100098_53': {'hadm_id': np.int64(100098),
#    'action_cluster_id': 53.0,
#    't0_time': Timestamp('2108-04-12 12:03:00+0000', tz='UTC'),
#    'file_path': 'data/context_tensors_output/physio_context/physio_context_100098_53.pt',
#    'n_intervals': 6,
#    'interval_minutes': 10,
#    'total_measurements': 24,
#    'has_data': True},
#   '100098_54': {'hadm_id': np.int64(100098),
#    'action_cluster_id': 54.0,
#    't0_time': Timestamp('2108-04-12 13:00:00+0000', tz='UTC'),
#    'file_path': 'data/context_tensors_output/physio_context/physio_context_100098_54.pt',
#    'n_intervals': 6,
#    'interval_minutes': 10,
#    'total_measurements': 24,
#    'has_data': True},
#   '100098_55': {'hadm_id': np.int64(100098),
#    'action_cluster_id': 55.0,
#    't0_time': Timestamp('2108-04-12 16:03:00+0000', tz='UTC'),
#    'file_path': 'data/context_tensors_output/physio_context/physio_context_100098_55.pt',
#    'n_intervals': 6,
#    'interval_minutes': 10,
# ...
