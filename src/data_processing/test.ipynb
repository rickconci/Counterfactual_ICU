# %%
import pickle

with open('/Users/riccardoconci/Local_documents/Counterfactual_ICU/data/mimic_3_data/med_tensors/trajectory_metadata.pkl', 'rb') as f:
    trajectory_metadata = pickle.load(f)

print(trajectory_metadata)
# Out:
# {'all_trajectories': {100061: [{'hadm_id': 100061, 'trajectory_num': 0, 'start_idx': 0, 'end_idx': np.int64(3), 'length': np.int64(3), 'start_time_hours': np.float64(0.0), 'end_time_hours': np.float64(0.03333333333333333), 'has_t0_trigger': np.True_, 'file_path': PosixPath('/Users/riccardoconci/Local_documents/Counterfactual_ICU/data/mimic_3_data/med_tensors/med_tensor_100061_traj_000.pt')}, {'hadm_id': 100061, 'trajectory_num': 1, 'start_idx': 0, 'end_idx': np.int64(1532), 'length': np.int64(1532), 'start_time_hours': np.float64(0.0), 'end_time_hours': np.float64(25.516666666666666), 'has_t0_trigger': np.True_, 'file_path': PosixPath('/Users/riccardoconci/Local_documents/Counterfactual_ICU/data/mimic_3_data/med_tensors/med_tensor_100061_traj_001.pt')}, {'hadm_id': 100061, 'trajectory_num': 2, 'start_idx': 0, 'end_idx': np.int64(2123), 'length': np.int64(2123), 'start_time_hours': np.float64(0.0), 'end_time_hours': np.float64(35.36666666666667), 'has_t0_trigger': np.True_, 'file_path
# ...

# %%
trajectory_metadata
# Out:
# {'all_trajectories': {100061: [{'hadm_id': 100061,
#     'trajectory_num': 0,
#     'start_idx': 0,
#     'end_idx': np.int64(3),
#     'length': np.int64(3),
#     'start_time_hours': np.float64(0.0),
#     'end_time_hours': np.float64(0.03333333333333333),
#     'has_t0_trigger': np.True_,
#     'file_path': PosixPath('/Users/riccardoconci/Local_documents/Counterfactual_ICU/data/mimic_3_data/med_tensors/med_tensor_100061_traj_000.pt')},
#    {'hadm_id': 100061,
#     'trajectory_num': 1,
#     'start_idx': 0,
#     'end_idx': np.int64(1532),
#     'length': np.int64(1532),
#     'start_time_hours': np.float64(0.0),
#     'end_time_hours': np.float64(25.516666666666666),
#     'has_t0_trigger': np.True_,
#     'file_path': PosixPath('/Users/riccardoconci/Local_documents/Counterfactual_ICU/data/mimic_3_data/med_tensors/med_tensor_100061_traj_001.pt')},
#    {'hadm_id': 100061,
#     'trajectory_num': 2,
#     'start_idx': 0,
#     'end_idx': np.int64(2123),
# ...
